# %% [markdown]
# # **Importing**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# # **Loading**

# %%
# Load the MNIST dataset
mnist = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
# Preprocess the data
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
# Build the neural network
model = keras.Sequential([
    layers.Flatten(input_shape=(28, 28)),  # Flatten the 28x28 image into a 1D array
    layers.Dense(128, activation='relu'),  # Fully connected layer with ReLU activation
    layers.Dropout(0.2),  # Dropout layer to reduce overfitting
    layers.Dense(10)  # Output layer with 10 units for 10 classes (0-9)
])

# %%
# Compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# # **Model Training**

# %%
# Train the model
model.fit(train_images, train_labels, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 15s 9ms/step - loss: 0.3267 - accuracy: 0.9050 - val_loss: 0.1577 - val_accuracy: 0.9542
# Epoch 2/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.1563 - accuracy: 0.9538 - val_loss: 0.1156 - val_accuracy: 0.9663
# Epoch 3/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1173 - accuracy: 0.9649 - val_loss: 0.1018 - val_accuracy: 0.9692
# Epoch 4/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0954 - accuracy: 0.9715 - val_loss: 0.0977 - val_accuracy: 0.9711
# Epoch 5/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0807 - accuracy: 0.9756 - val_loss: 0.0868 - val_accuracy: 0.9746
# Epoch 6/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0708 - accuracy: 0.9774 - val_loss: 0.0815 - val_accuracy: 0.9748
# Epoch 7/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0609 - accuracy: 0.9810 - val_loss: 0.0858 - val_accuracy: 0.9758
# Epoch 8/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0551 - accuracy: 0.9823 - val_loss: 0.0832 - val_accuracy: 0.9760
# Epoch 9/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0486 - accuracy: 0.9840 - val_loss: 0.0852 - val_accuracy: 0.9773
# Epoch 10/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0471 - accuracy: 0.9843 - val_loss: 0.0803 - val_accuracy: 0.9768

# %% [markdown]
# # **Evaluation**

# %%
# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate(test_images, test_labels, verbose=2)
print("\nTest accuracy:", test_accuracy)
# Out:
# 313/313 - 1s - loss: 0.0733 - accuracy: 0.9777 - 624ms/epoch - 2ms/step
#
# Test accuracy: 0.9776999950408936

# %% [markdown]
# We import TensorFlow and load the MNIST dataset using keras.datasets.mnist.
#
# The data is preprocessed by scaling pixel values to a range of [0, 1].
#
# We build a simple neural network using the Sequential API. It consists of a flattening layer, a dense layer with ReLU activation, a dropout layer for regularization, and the output layer with 10 units for 10 classes.
#
# The model is compiled with the Adam optimizer, sparse categorical cross-entropy loss, and accuracy as the evaluation metric.
#
# We train the model on the training data for 10 epochs.
#
# Finally, the model is evaluated on the test data to calculate its accuracy.
